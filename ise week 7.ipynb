# %%
# import pandas as pd
import pandas as pd

# list of strings
list_1 = ["CSC", "Ise", "Karol", "Ebube", "physics"]

# create DataFrame
df = pd.DataFrame(list_1)

# Print the output
df
# Out:
#          0
# 0      CSC
# 1      Ise
# 2    Karol
# 3    Ebube
# 4  physics

# %%
# import pandas as pd
import pandas as pd

# initialize data of lists
data = {"Name":['Angel','Ise','Joseph','Oyinda'],
        "Age":[20, 21, 22, 23]}

# create DataFrame
df = pd.DataFrame(data)

df
# Out:
#      Name  Age
# 0   Angel   20
# 1     Ise   21
# 2  Joseph   22
# 3  Oyinda   23

# %%
# import pandas package
import pandas as pd

# Define a dictionary containing employee data
data ={"Name":["fope", "Clement", "Karol", "Prince"],
       "Age": [26, 24, 23, 42],
        "Address":["Surulere", "Kano", "Minna", "Lagos"],
         "Qualification":["Msc", "MA", "MCA", "PHd"]}

fc = pd.DataFrame(data)

# selecting 2 solumns
fc[["Name",  "Qualification"]]
# Out:
#       Name Qualification
# 0     fope           Msc
# 1  Clement            MA
# 2    Karol           MCA
# 3   Prince           PHd

# %%
import pandas as pd


# Define a dictionary containing employee data
data ={"Name":["fope", "Clement", "Karol", "Prince"],
       "Age": [26, 24, 23, 42],
        "Address":["Surulere", "Kano", "Minna", "Lagos"],
         "Qualification":["Msc", "MA", "MCA", "PHd"]}

# Convert the dictionary containing employee data
df = pd.DataFrame(data)

# Select first row
df.iloc[1]
# Out:
# Name             Clement
# Age                   24
# Address             Kano
# Qualification         MA
# Name: 1, dtype: object

# %%
import pandas as pd

data = pd.read_csv("bcg.csv")

df = data.iloc[0]

df
# Out:
# Employee Names       Matthew Ade
# Years                         25
# Assesment Records          125.3
# Points                        21
# Reward                    438.55
# Name: 0, dtype: object

# %%
import pandas as pd

# importing the csv file using pandas
data = pd.read_csv("Top-Apps-in-Google-Play.csv")

df = data.head(7)
df
# Out:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# 6                    com.google.android.gm            Communication
#
# ...

# %%
# Out:
# Unnamed: 0                                                           2
# App Name                                                       YouTube
# App Id                                      com.google.android.youtube
# Category                                       Video Players & Editors
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/youtube/topic/24225...
# Developer Email                           ytandroid-support@google.com
# Content Rating                                                    Teen
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 1, dtype: object

# %%
import pandas as pd

data = pd.read_csv("Top-Apps-in-Google-Play.csv")

data[["App Name", "App Id","Category"]]
# Out:
#                                              App Name  \
# 0                                Google Play services
# 1                                             YouTube
# 2                                              Google
# 3                    Google Maps - Navigate & Explore
# 4                               Google Text-to-Speech
# ..                                                ...
# 65                                              Clock
# 66  Spotify: Listen to podcasts & find music you love
# 67                                   Google Translate
# 68                                      Samsung Notes
# 69                                         Calculator
#
#                                      App Id                 Category
# 0                    com.google.android.gms                    Tools
# 1                com.google.android.youtube  Video Players & Editors
# 2   com.google.android.googlequicksearchbox                    Tools
# ...

# %%
import pandas as pd

data = pd.read_csv("Top-Apps-in-Google-Play.csv")

df = data.head(1)
df
# Out:
#    Unnamed: 0              App Name                  App Id Category  \
# 0           1  Google Play services  com.google.android.gms    Tools
#
#   Developer Id                                  Developer Website  \
# 0   Google LLC  https://developers.google.com/android/google-p...
#
#         Developer Email Content Rating  Ad Supported  In App Purchases
# 0  apps-help@google.com       Everyone         False             False

# %% [markdown]
# ### Class  Project 2

# %%
import pandas as pd

data = {"Export":["Refreshment Beverages", "Confectionary", "Intermidiate Cocoa Products"],
        "Segment":["Manufacture and sale of Bournvita and Chocolate", "Manufacture and sale of TomTom and Buttermint", "Manufacture and sale of cocoa powder, cocoa butter, cocoa liquor and cocoa cake"],
        "Brands":["CADBURY BOURNVITA and CADBURY 3-in-1 HOT CHOCOLATE", "TOMTOM CLASSIC, TOMTOM STRAWBERRY and BUTTERMINT", "COCOA POWDER and COCOA BUTTER"]},
df = pd.DataFrame(data)

df
# Out:
#                                               Export  \
# 0  [Refreshment Beverages, Confectionary, Intermi...
#
#                                              Segment  \
# 0  [Manufacture and sale of Bournvita and Chocola...
#
#                                               Brands
# 0  [CADBURY BOURNVITA and CADBURY 3-in-1 HOT CHOC...
